# %% [markdown]
# # **Data Cleaning & Data Analysis**
#
# ---

# %%
import pandas as pd
from numpy import nan
import plotly.express as px

# %% [markdown]
# ### **Reading Open Pubs and Data Dictionary Datasets**

# %%
df1 = pd.read_csv(r'/content/open_pubs.csv')
df2 = pd.read_csv(r'/content/data_dictionary - Sheet1.csv')

# %% [markdown]
# ### **Getting Overview about both the datasets**

# %%
df1.head()
# Out:
#    22          Anchor Inn        Upper Street, Stratford St Mary, COLCHESTER  \
# 0  36  Ark Bar Restaurant  Ark Bar And Restaurant, Cattawade Street, Bran...
# 1  74           Black Boy  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...
# 2  75         Black Horse        Lower Street, Stratford St Mary, COLCHESTER
# 3  76          Black Lion                      Lion Road, Glemsford, SUDBURY
# 4  97        Brewers Arms  The Brewers Arms, Bower House Tye, Polstead, C...
#
#     CO7 6LW  604749   234404  51.970379  0.979340  Babergh
# 0  CO11 1RH  610194   233329  51.958698  1.057832  Babergh
# 1  CO10 2EA  587334   241316  52.038595  0.729915  Babergh
# 2   CO7 6JS  622675 -5527598         \N        \N  Babergh
# 3  CO10 7RF  622675 -5527598         \N        \N  Babergh
# 4   CO6 5BZ  598743   240655  52.028694  0.895650  Babergh

# %%
df2.head()
# Out:
#       Field Possible Values                                 Comments
# 0    fsa_id             int  Food Standard Agency's ID for this pub.
# 1      name          string                         Name of the pub.
# 2   address          string      Address fields separated by commas.
# 3  postcode          string                     Postcode of the pub.
# 4   easting             int                                      NaN

# %% [markdown]
# ### **Iterating over Labels Dataset and adding it to a list**

# %%
field_names = df2["Field"]

names = []

for i in range(len(field_names)):
    names.append(field_names[i])

# %%
df1.columns = names

# %% [markdown]
# ### **Verifying the Output after adding cloumn names**

# %%
df1.head(2)
# Out:
#    fsa_id                name  \
# 0      36  Ark Bar Restaurant
# 1      74           Black Boy
#
#                                              address  postcode  easting  \
# 0  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
#
#    northing   latitude longitude local_authority
# 0    233329  51.958698  1.057832         Babergh
# 1    241316  52.038595  0.729915         Babergh

# %% [markdown]
# ### **Replacing the N/A values to NaN**

# %%
df1.replace(r"\N", nan, inplace=True)
df1.head()
# Out:
#    fsa_id                name  \
# 0      36  Ark Bar Restaurant
# 1      74           Black Boy
# 2      75         Black Horse
# 3      76          Black Lion
# 4      97        Brewers Arms
#
#                                              address  postcode  easting  \
# 0  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 2        Lower Street, Stratford St Mary, COLCHESTER   CO7 6JS   622675
# 3                      Lion Road, Glemsford, SUDBURY  CO10 7RF   622675
# 4  The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
#
#    northing   latitude longitude local_authority
# 0    233329  51.958698  1.057832         Babergh
# 1    241316  52.038595  0.729915         Babergh
# 2  -5527598        NaN       NaN         Babergh
# 3  -5527598        NaN       NaN         Babergh
# 4    240655  52.028694  0.895650         Babergh

# %%
df1.dropna(inplace=True)

# %% [markdown]
# ### **Verifying the Output after dropping NaN values**

# %%
df1.head()
# Out:
#    fsa_id                name  \
# 0      36  Ark Bar Restaurant
# 1      74           Black Boy
# 4      97        Brewers Arms
# 5     102        Bristol Arms
# 6     122     Caffeine Lounge
#
#                                              address  postcode  easting  \
# 0  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 4  The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 5                     Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
# 6  14 Borehamgate Shopping Precinct, King Street,...  CO10 2ED   587527
#
#    northing   latitude longitude local_authority
# 0    233329  51.958698  1.057832         Babergh
# 1    241316  52.038595  0.729915         Babergh
# 4    240655  52.028694  0.895650         Babergh
# 5    233550  51.955042  1.267642         Babergh
# 6    241247  52.037903  0.732687         Babergh

# %% [markdown]
# ### **Storing the new and cleaned dataset**

# %%
df1.to_csv(r"/content/clean_dataset.csv", index=False)

# %% [markdown]
# ### **Verifying the New Dataset**

# %%
df_clean = pd.read_csv(r"/content/clean_dataset.csv")

# %%
df_clean.head()
# Out:
#    fsa_id                name  \
# 0      36  Ark Bar Restaurant
# 1      74           Black Boy
# 2      97        Brewers Arms
# 3     102        Bristol Arms
# 4     122     Caffeine Lounge
#
#                                              address  postcode  easting  \
# 0  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 2  The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 3                     Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
# 4  14 Borehamgate Shopping Precinct, King Street,...  CO10 2ED   587527
#
#    northing   latitude  longitude local_authority
# 0    233329  51.958698   1.057832         Babergh
# 1    241316  52.038595   0.729915         Babergh
# 2    240655  52.028694   0.895650         Babergh
# 3    233550  51.955042   1.267642         Babergh
# 4    241247  52.037903   0.732687         Babergh

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**
#
# ---

# %% [markdown]
# ### **Getting the Head and Tail of Dataset**

# %%
df_clean.head()
# Out:
#    fsa_id                name  \
# 0      36  Ark Bar Restaurant
# 1      74           Black Boy
# 2      97        Brewers Arms
# 3     102        Bristol Arms
# 4     122     Caffeine Lounge
#
#                                              address  postcode  easting  \
# 0  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 1  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 2  The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 3                     Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
# 4  14 Borehamgate Shopping Precinct, King Street,...  CO10 2ED   587527
#
#    northing   latitude  longitude local_authority
# 0    233329  51.958698   1.057832         Babergh
# 1    241316  52.038595   0.729915         Babergh
# 2    240655  52.028694   0.895650         Babergh
# 3    233550  51.955042   1.267642         Babergh
# 4    241247  52.037903   0.732687         Babergh

# %%
df_clean.tail()
# Out:
#        fsa_id                                      name  \
# 50558  597119  Wrexham & District War Memorial Club Ltd
# 50559  597127                 Wrexham Lager Social Club
# 50560  597130         Wrexham Rail Sports & Social Club
# 50561  597131                        Wrexham Rugby Club
# 50562  597137                                     Y Tai
#
#                                                  address  postcode  easting  \
# 50558  Wrexham War Memorial Club Farndon Street, Wrex...  LL13 8DE   333909
# 50559                 1 - 3 Union Road, Wrexham, Wrexham  LL13 7SR   333028
# 50560  Sports And Social Club, 44 Brook Street, Wrexh...  LL13 7LU   333259
# 50561  Wrexham Rugby Club Bryn Estyn Road, Wrexham, W...  LL13 9TY   335808
# 50562       Y Tai Railway Road, Brymbo, Wrexham, Wrexham  LL11 5EA   329721
#
#        northing   latitude  longitude local_authority
# 50558    350438  53.047100  -2.987319         Wrexham
# 50559    350563  53.048123  -3.000485         Wrexham
# 50560    350213  53.044998  -2.996966         Wrexham
# 50561    351078  53.053094  -2.959124         Wrexham
# 50562    353785  53.076638  -3.050512         Wrexham

# %% [markdown]
# ### **Getting the general Info. of the Dataset**

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50563 entries, 0 to 50562
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           50563 non-null  int64
#  1   name             50563 non-null  object
#  2   address          50563 non-null  object
#  3   postcode         50563 non-null  object
#  4   easting          50563 non-null  int64
#  5   northing         50563 non-null  int64
#  6   latitude         50563 non-null  float64
#  7   longitude        50563 non-null  float64
#  8   local_authority  50563 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 3.5+ MB

# %% [markdown]
# ### **Describing the Dataset**

# %%
df_clean.describe()
# Out:
#               fsa_id        easting      northing      latitude     longitude
# count   50563.000000   50563.000000  5.056300e+04  50563.000000  50563.000000
# mean   299401.170441  426929.051144  3.144895e+05     52.718772     -1.618317
# std    169230.654390   96375.663150  1.662817e+05      1.497436      1.415450
# min        36.000000   78110.000000  8.196000e+03     49.892485     -7.384525
# 25%    168003.000000  360193.000000  1.808110e+05     51.512366     -2.590561
# 50%    303676.000000  427205.000000  2.904810e+05     52.502652     -1.584745
# 75%    439353.000000  505380.500000  4.101270e+05     53.585197     -0.449987
# max    597137.000000  655277.000000  1.209661e+06     60.764969      1.757763

# %% [markdown]
# ### **Getting the number of pubs by Name**

# %%
df_clean["name"].value_counts()
# Out:
# The Red Lion                               193
# The Royal Oak                              170
# Red Lion                                   130
# The Crown Inn                              112
# Royal Oak                                  102
#                                           ...
# Morecambe Golf Club - Catering               1
# Morecambe Golf Club                          1
# Morecambe Cricket Club                       1
# Morecambe & Heysham Constitutional Club      1
# Y Tai                                        1
# Name: name, Length: 35809, dtype: int64

# %% [markdown]
# ### **Getting number of pubs per location (with Graph)**

# %%
df = df_clean

count = df["local_authority"].value_counts()
count2 = df["local_authority"].unique()

fig = px.bar(df,
             x=count2,
             y=count,
             title="Number of Pubs per location",
             labels={'x': 'Locations','y':'Pub Count'},
             color=count)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bb6a5f10-99cd-436a-ac53-ac12610a4094" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb6a5f10-99cd-436a-ac53-ac12610a4094")) {                    Plotly.newPlot(                        "bb6a5f10-99cd-436a-ac53-ac12610a4094",                        [{"alignmentgroup":"True","hovertemplate":"Locations=%{x}<br>Pub Count=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[680,611,557,544,524,506,494,485,478,446,432,415,408,405,404,370,356,356,353,348,345,340,326,306,305,298,293,293,293,284,283,279,279,262,261,252,247,244,240,239,229,222,221,221,219,219,219,218,215,213,212,211,208,208,205,205,205,201,200,194,193,191,188,188,188,188,186,185,185,185,184,184,181,180,180,179,179,178,176,176,176,175,174,174,172,172,171,171,168,168,166,165,165,165,165,163,163,162,162,162,161,160,159,159,157,155,155,154,153,152,152,152,152,152,151,151,149,149,149,148,146,146,146,145,143,143,143,142,141,140,139,139,137,137,136,136,135,133,133,132,131,131,131,130,130,130,129,129,127,127,127,127,127,126,126,125,125,124,123,122,122,122,122,122,121,121,120,120,120,120,118,118,118,118,117,117,115,115,115,115,114,114,113,113,113,112,112,112,112,110,109,109,108,108,108,108,108,108,107,107,107,106,106,105,105,105,104,104,104,104,103,102,102,102,102,101,101,101,101,101,101,100,100,99,99,99,99,99,98,97,96,96,96,96,95,94,94,93,93,93,92,91,91,91,91,91,91,90,90,90,88,88,88,88,87,87,86,86,85,85,85,84,83,83,83,82,81,80,80,80,80,79,79,77,76,76,76,76,75,75,74,72,72,72,72,72,70,69,68,68,67,67,65,64,63,63,63,63,63,63,63,62,62,62,62,62,61,60,60,59,59,59,59,58,57,56,55,55,55,54,54,53,52,52,52,50,50,50,49,48,48,48,48,48,48,47,47,47,46,45,43,43,42,41,41,39,38,35,33,31,29,28,27,27,26,15,12,11,10,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Babergh","Mid Suffolk","Basildon","Bedford","Huntingdonshire","Braintree","Breckland","Brentwood","Broadland","Broxbourne","Cambridge","Castle Point","Central Bedfordshire","Luton","Dacorum","Chelmsford","Rochford","Colchester","East Cambridgeshire","East Hertfordshire","East Suffolk","Epping Forest","Redbridge","Fenland","Great Yarmouth","Harlow","Hertsmere","Ipswich","King's Lynn and West Norfolk","Maldon","North Hertfordshire","North Norfolk","Norwich","South Norfolk","Peterborough","South Cambridgeshire","Southend-on-Sea","St Albans","Stevenage","Tendring","Three Rivers","Thurrock","Uttlesford","Watford","Welwyn Hatfield","West Suffolk","Amber Valley","Ashfield","Bassetlaw","Blaby","Bolsover","Boston","Broxtowe","Charnwood","Chesterfield","Derby","Derbyshire Dales","East Lindsey","Erewash","Gedling","Nottingham","Harborough","High Peak","Hinckley and Bosworth","Leicester","Lincoln","Mansfield","Melton","Newark and Sherwood","North East Derbyshire","North Kesteven","North Northamptonshire","North West Leicestershire","Oadby and Wigston","Rushcliffe","Rutland","South Derbyshire","East Staffordshire","South Holland","South Kesteven","West Lindsey","West Northamptonshire","Barking and Dagenham","Barnet","Bexley","Brent","Harrow","Bromley","Croydon","Camden","City of London","Lambeth","Ealing","Enfield","Waltham Forest","Greenwich","Hackney","Tower Hamlets","Hammersmith and Fulham","Haringey","Havering","Hillingdon","Hounslow","Islington","Kensington and Chelsea","Kingston upon Thames","Lewisham","Merton","Newham","Richmond upon Thames","Wandsworth","Southwark","Sutton","Westminster","Darlington","County Durham","Gateshead","Hartlepool","Middlesbrough","Newcastle upon Tyne","North Tyneside","Northumberland","Redcar and Cleveland","South Tyneside","Stockton-on-Tees","Sunderland","Allerdale","Barrow-in-Furness","Blackburn with Da ...

# %% [markdown]
# ### **Getting Lat-Lon Realationship (with Graph)**

# %%
df = df_clean
fig = px.scatter(x=df["latitude"],
                 y=df["longitude"],
                 labels={'x': 'Latitude','y':'Longitude'},
                 color=df["latitude"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3515e277-ccbd-4194-872a-9c11d4bf7768" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3515e277-ccbd-4194-872a-9c11d4bf7768")) {                    Plotly.newPlot(                        "3515e277-ccbd-4194-872a-9c11d4bf7768",                        [{"hovertemplate":"Latitude=%{x}<br>Longitude=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":